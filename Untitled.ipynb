# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
credito = pd.read_csv("salario_vs_sexo_vs_limite.csv")

# %%
credito.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   sexo                     9 non-null      object
#  1   salario_anual            9 non-null      object
#  2   limite_medio_vs_salario  9 non-null      float64
#  3   numero_individuos        9 non-null      int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 420.0+ bytes

# %%
sns.barplot(
    data = credito,
    x = "salario_anual",
    y =  "limite_medio_vs_salario",
    hue = "sexo",
    palette = {"M": "blue", "F":"pink"}
)
plt.xticks(rotation = 45)
plt.savefig("Grafico salario vs limite vs genero")
plt.show()
