# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
credito = pd.read_csv("salario_vs_sexo_vs_limite.csv")

# %%
credito.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   sexo                     9 non-null      object
#  1   salario_anual            9 non-null      object
#  2   limite_medio_vs_salario  9 non-null      float64
#  3   numero_individuos        9 non-null      int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 420.0+ bytes

# %%
sns.barplot(
    data = credito,
    x = "salario_anual",
    y =  "limite_medio_vs_salario",
    hue = "sexo",
    palette = {"M": "blue", "F":"pink"}
)
plt.xticks(rotation = 45)
plt.savefig("Grafico salario vs limite vs genero", dpi = 300, bbox_inches="tigt")
plt.show()

# %%
df = pd.read_csv("credito.csv", header = None)
df.head()
df.columns = ["idade", "sexo", "dependentes", "escolaridade", "estado_civil", "salario_anual", "tipo_cartao", "qtd_produtos", "iteracoes_12m", "meses_inativo_12m", "limite_credito", "valor_transacoes_12m", "qtd_transacoes_12m"]

# %%
df.head()
# Out:
#    idade sexo  dependentes         escolaridade estado_civil   salario_anual  \
# 0     45    M            3         ensino medio       casado     $60K - $80K
# 1     49    F            5             mestrado     solteiro  menos que $40K
# 2     51    M            3             mestrado       casado    $80K - $120K
# 3     40    F            4         ensino medio           na  menos que $40K
# 4     40    M            3  sem educacao formal       casado     $60K - $80K
#
#   tipo_cartao  qtd_produtos  iteracoes_12m  meses_inativo_12m  limite_credito  \
# 0        blue             5              3                  1        12691.51
# 1        blue             6              2                  1         8256.96
# 2        blue             4              0                  1         3418.56
# 3        blue             3              1                  4         3313.03
# 4        blue             5              0                  1         4716.22
#
# ...

# %%
tipo_cartao_vs_limite = pd.read_csv("tipo_cartao vs average limit.csv")
sns.barplot(data = tipo_cartao_vs_limite,x = "tipo_cartao", y = "media_limite")
plt.savefig("tipo_cartao_vs_media_limite", dpi = 300, bbox_inches = "tight")
plt.show()
